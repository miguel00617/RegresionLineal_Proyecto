# %% [markdown]
# # Predicción de Precio de Viviendas

# %% [markdown]
# ## Regresión Lineal Simple

# %% [markdown]
# Primero, cabe explicar como funcionará este proyecto de Machine Learning. Consta de dos partes, aprendizaje automático y por último una pequeña web donde tiene una interfaz gráfica para poder interactuar con el algoritmo, vamos con lo primero

# %% [markdown]
# Hagamos una breve explicación de como se saca el precio(siempre en dólares), una pequeña fórmula: Depto.Precio= m2 * área + base
# Depto.Precio= 2000 * 40 + 30000= 110 000

# %%
#Empecemos reuniendo las herramientas necesarias para este proyecto:

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.metrics import r2_score, mean_squared_error
import matplotlib.pyplot as plt

# %%
#Hacemos la lectura de nuestro archivo

# %%
df = pd.read_csv("C:\\Users\\USUARIO\\Downloads\\depto_csv.txt")
df
# Out:
#    area   price
# 0    40  110000
# 1    50  130000
# 2    60  150000
# 3    70  170000
# 4    80  190000
# 5    90  210000

# %%
#Ya teniendo nuestro data frame, vamos a visualizar su relación en un gráfico de dispersión

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.scatter(df.area, df.price, color='red', marker='+', s=100, label='Datos reales')
#Línea de regresión
area_range = np.linspace(df.area.min(), df.area.max(), 100)
price_pred = reg.predict(area_range.reshape(-1, 1))
plt.plot(area_range, price_pred, color='blue', linewidth=2, label='Línea de regresión')

plt.xlabel('Área')
plt.ylabel('Precio')
plt.title('Regresión Lineal: Área vs Precio')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# C:\Users\USUARIO\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Separemos las dos columnas, asi agilizamos su proceso

# %%
area= df.drop('price',axis='columns')
area
# Out:
#    area
# 0    40
# 1    50
# 2    60
# 3    70
# 4    80
# 5    90

# %%
price = df.price
price
# Out:
# 0    110000
# 1    130000
# 2    150000
# 3    170000
# 4    190000
# 5    210000
# Name: price, dtype: int64

# %%
# Creamos el modelo de regresión, que será el algoritmo que automatizará el cálculo
reg = linear_model.LinearRegression()
reg.fit(area,price)
# Out:
# LinearRegression()

# %%
#Marquemos y veamos cual es el rango de error que tiene este algoritmo

# %%
r2_simple = reg.score(area, price)

# %%
r2_simple
# Out:
# 1.0

# %% [markdown]
# **Primera predicción, área de 35 m**

# %%
reg.predict([[35]])
# Out:
# C:\Users\USUARIO\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([100000.])

# %% [markdown]
# **Nos da un total de 100000 dólares**

# %%
#Identificamos el coeficiente y el intercepto, propiedades de la fórmula de regresión lineal en Machine Learning

# %%
reg.coef_
# Out:
# array([2000.])

# %%
reg.intercept_
# Out:
# 30000.0

# %% [markdown]
# **Y = m * X + b (m es el coeficiente y b es el intercepto)**
